# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')  # esto es para quitar prints

pd.set_option('display.max_columns', None)

# %%
import csv

# %%
data_sha = pd.read_csv(r'..\Data\attacks.csv', encoding='latin1')

# %%
data_sha.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %%
sharks = data_sha.copy()

# %%
sharks.shape
# Out:
# (25723, 24)

# %%
sharks.info(memory_usage = "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 22.8 MB

# %%
nan_cols=sharks.isna().mean() * 100
nan_cols[nan_cols>0]
# Out:
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %%
# %pip install ipython
# %pip install seaborn
# Out:
# Requirement already satisfied: ipython in c:\users\pabli\anaconda3\lib\site-packages (8.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (3.0.20)
# Requirement already satisfied: colorama in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (61.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: decorator in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: backcall in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\pabli\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\pabli\anaconda3\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\pabli\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.5)
# Requirement already satisfied: executing in c:\users\pabli\anaconda3\lib\site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\pabli\anaconda3\lib\site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\pabli\anaconda3\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in c:\users\pabli\anaconda3\lib\site-packages (from asttokens->stack-data->ipython) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\pabli\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\pabli\anaconda3\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\pabli\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: pandas>=0.23 in c:\users\pabli\anaconda3\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\pabli\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pabli\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pabli\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\pabli\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# para pintar
import pylab as plt
import seaborn as sns

#para que salga el grafico
# %matplotlib inline

# %%
def check_nan(data: pd.DataFrame) -> None:
    
    nan_cols=data.isna().mean() * 100  # el porcentaje
    
    display(f'N nan cols: {len(nan_cols[nan_cols>0])}')
    display(nan_cols[nan_cols>0])
    
    plt.figure(figsize=(10, 6))  # inicia la figura y establece tamaño

    sns.heatmap(data.isna(),  # mapa de calor
                yticklabels=False,
                cmap='viridis',
                cbar=False)

    plt.show()

# %%
check_nan(sharks)
# Out:
# 'N nan cols: 24'
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %%
# Drop Both Unnamed columns
sharks.drop(columns=nan_cols[nan_cols>98].index, inplace=True)

# %%
check_nan(sharks)
# Out:
# 'N nan cols: 22'
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# dtype: float64

# %%
bad_index_Date=sharks.Date[sharks.Date.isna()].index

# %%
bad_index_Date[:10]
# Out:
# Int64Index([6302, 6303, 6304, 6305, 6306, 6307, 6308, 6309, 6310, 6311], dtype='int64')

# %%
bad_index_Year=sharks.Year[sharks.Year.isna()].index

# %%
bad_index_Year[:10]
# Out:
# Int64Index([187, 6079, 6302, 6303, 6304, 6305, 6306, 6307, 6308, 6309], dtype='int64')

# %%
# crear un indicador de nulos por fila

# desglosado


num_nan=[]

for fila in sharks.itertuples():
    
    check=[]
    
    for e in fila:
        
        check.append(pd.isna(e))
        
    num_nan.append(sum(check))
    
num_nan[:23]
# Out:
# [0, 1, 1, 2, 2, 3, 0, 1, 0, 1, 0, 2, 1, 0, 1, 2, 1, 3, 0, 2, 1, 0, 1]

# %%
sharks['num_nan']=[sum([pd.isna(e) for e in fila]) for fila in sharks.itertuples()]

# %%
sharks[sharks.num_nan>20].shape
# Out:
# (19414, 23)

# %%
sharks.shape
# Out:
# (25723, 23)

# %%
sharks1 = sharks.copy()

# %%
sharks1.drop(sharks1[sharks1.num_nan>20].index, axis=0, inplace=True)

# %%
sharks1.shape
# Out:
# (6309, 23)

# %%
check_nan(sharks1)
# Out:
# 'N nan cols: 21'
# Case Number                0.015850
# Date                       0.110953
# Year                       0.142653
# Type                       0.174354
# Country                    0.903471
# Area                       7.322872
# Location                   8.670154
# Activity                   8.733555
# Name                       3.439531
# Sex                        9.066413
# Age                       44.983357
# Injury                     0.554763
# Fatal (Y/N)                8.654303
# Time                      53.273102
# Species                   45.094310
# Investigator or Source     0.380409
# pdf                        0.110953
# href formula               0.126803
# href                       0.110953
# Case Number.1              0.110953
# Case Number.2              0.110953
# dtype: float64

# %%
sharks1["Species "].head()
# Out:
# 0        White shark
# 1                NaN
# 2                NaN
# 3          2 m shark
# 4    Tiger shark, 3m
# Name: Species , dtype: object

# %%
new_column = []
for c in sharks1.columns:
    c = c.replace(" ","")
    c = c.replace(".","")
    c = c.replace("Fatal(Y/N)","Fatal_bin")
    
    new_column.append(c)
sharks1.columns = new_column

# %%
sharks1.columns
# Out:
# Index(['CaseNumber', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Injury', 'Fatal_bin', 'Time',
#        'Species', 'InvestigatororSource', 'pdf', 'hrefformula', 'href',
#        'CaseNumber1', 'CaseNumber2', 'originalorder', 'num_nan'],
#       dtype='object')

# %%
sharks1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               Injury Fatal_bin           Time  \
# 0  No injury to occupant, outrigger canoe and pad...         N          18h00
# 1                         Minor injury to left thigh         N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg         N          07h45
# 3                          Minor injury to lower leg         N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT         N            NaN
#
#            Species            InvestigatororSource                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                          hrefformula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href CaseNumber1 CaseNumber2  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.25  2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.18  2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.09  2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.08  2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.04  2018.06.04
#
#    originalorder  num_nan
# 0         6303.0        0
# 1         6302.0        1
# 2         6301.0        1
# 3         6300.0        2
# 4         6299.0        2

# %%
sharks1.dtypes
# Out:
# CaseNumber               object
# Date                     object
# Year                    float64
# Type                     object
# Country                  object
# Area                     object
# Location                 object
# Activity                 object
# Name                     object
# Sex                      object
# Age                      object
# Injury                   object
# Fatal_bin                object
# Time                     object
# Species                  object
# InvestigatororSource     object
# pdf                      object
# hrefformula              object
# href                     object
# CaseNumber1              object
# CaseNumber2              object
# originalorder           float64
# num_nan                   int64
# dtype: object

# %%
sharks1.Country.value_counts()
# Out:
# USA                       2229
# AUSTRALIA                 1338
# SOUTH AFRICA               579
# PAPUA NEW GUINEA           134
# NEW ZEALAND                128
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: Country, Length: 212, dtype: int64

# %%
sharks1.Country.fillna('unknown', inplace=True)

# %%
check_nan(sharks1)
# Out:
# 'N nan cols: 20'
# CaseNumber               0.015850
# Date                     0.110953
# Year                     0.142653
# Type                     0.174354
# Area                     7.322872
# Location                 8.670154
# Activity                 8.733555
# Name                     3.439531
# Sex                      9.066413
# Age                     44.983357
# Injury                   0.554763
# Fatal_bin                8.654303
# Time                    53.273102
# Species                 45.094310
# InvestigatororSource     0.380409
# pdf                      0.110953
# hrefformula              0.126803
# href                     0.110953
# CaseNumber1              0.110953
# CaseNumber2              0.110953
# dtype: float64

# %%
bad_index_Area=sharks1.Area[sharks.Area.isna()].index
bad_index_Area[:10]
# Out:
# Int64Index([32, 33, 48, 56, 59, 62, 90, 101, 129, 132], dtype='int64')

# %%
bad_index_Location=sharks1.Location[sharks.Location.isna()].index
bad_index_Location[:10]
# Out:
# Int64Index([56, 62, 101, 110, 132, 151, 171, 174, 180, 187], dtype='int64')

# %%
sharks1.iloc[bad_index_Area]
# Out:
#         CaseNumber                  Date    Year          Type        Country  \
# 32      2018.04.09           09-Apr-2018  2018.0    Unprovoked  NEW CALEDONIA
# 33      2018.04.05           05-Apr-2018  2018.0    Unprovoked        BAHAMAS
# 48      2018.01.21           21-Jan-2018  2018.0    Unprovoked  NEW CALEDONIA
# 56      2017.12.09           09-Dec-2017  2017.0    Unprovoked        BAHAMAS
# 59    2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster          LIBYA
# ...            ...                   ...     ...           ...            ...
# 6304             0                   NaN     NaN           NaN        unknown
# 6305             0                   NaN     NaN           NaN        unknown
# 6306             0                   NaN     NaN           NaN        unknown
# 6307             0                   NaN     NaN           NaN        unknown
# 6308             0                   NaN     NaN           NaN        unknown
#
#      Area               Location          Activity                 Name  Sex  \
# 32    NaN  Magenta Beach, Noumea       Windsurfing                  NaN  NaN
# 33    NaN                 Bimini          Swimming      Shane McConnell    M
# 48    NaN               Nouville      Spearfishing                 male    M
# 56    NaN                    NaN        Snorkeling  Sarah Illig-Carroll    F
# 59    NaN         Gars Garabulli  2 boats capsized          31 migrants  NaN
# ...   ...                    ...               ...                  ...  ...
# 6304  NaN                    NaN               NaN                  NaN  NaN
# 6305  NaN                    NaN               NaN                  NaN  NaN
# 6306  NaN                    NaN               NaN                  NaN  NaN
# 6307  NaN                    NaN               NaN                  NaN  NaN
# 6308  NaN                    NaN               NaN                  NaN  NaN
#
#       Age                                             Injury Fatal_bin   Time  \
# 32    NaN                         No injury, shark bit board         N  17h00
# 33     12  2 puncture wounds to left foot, abrasion to ri...         N  18h00
# 48    40s                        Injuries to abdomen and arm         N  15h30
# 56     25                                Minor injury to arm         N    NaN
# 59    NaN                                              FATAL         Y    NaN
# ...   ...                                                ...       ...    ...
# 6304  NaN                                                NaN       NaN    NaN
# 6305  NaN                                                NaN       NaN    NaN
# 6306  NaN                                                NaN       NaN    NaN
# 6307  NaN                                                NaN       NaN    NaN
# 6308  NaN                                                NaN       NaN    NaN
#
#                                                 Species  \
# 32                                            2 m shark
# 33                                           Bull shark
# 48                                     Bull shark, 3 m
# 56                                      Nurse shark. 5'
# 59    Some drowned but other may have been killed by...
# ...                                                 ...
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                         InvestigatororSource                          pdf  \
# 32    Les Nouvelles Caledoniennes, 4/10/2018       2018.04.09-Magenta.pdf
# 33           K. McMurray, TrackingSharks.com     2018.04.05-McConnell.pdf
# 48                        TrackingSharks.com  2018.01.21-NewCaledonia.pdf
# 56                    Daily Star, 12/11/2017       2017.12.09-Carroll.pdf
# 59                     TG Com 24, 11/25/2017       2017.11.25.R-Libya.pdf
# ...                                      ...                          ...
# 6304                                     NaN                          NaN
# 6305                                     NaN                          NaN
# 6306                                     NaN                          NaN
# 6307                                     NaN                          NaN
# 6308                                     NaN                          NaN
#
#                                             hrefformula  \
# 32    http://sharkattackfile.net/spreadsheets/pdf_di...
# 33    http://sharkattackfile.net/spreadsheets/pdf_di...
# 48    http://sharkattackfile.net/spreadsheets/pdf_di...
# 56    http://sharkattackfile.net/spreadsheets/pdf_di...
# 59    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                                                    href   CaseNumber1  \
# 32    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.09
# 33    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.05
# 48    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.01.21
# 56    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.12.09
# 59    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.11.25.R
# ...                                                 ...           ...
# 6304                                                NaN           NaN
# 6305                                                NaN           NaN
# 6306                                                NaN           NaN
# 6307                                                NaN           NaN
# 6308                                                NaN           NaN
#
#        CaseNumber2  originalorder  num_nan
# 32      2018.04.09         6271.0        4
# 33      2018.04.05         6270.0        1
# 48      2018.01.21         6255.0        1
# 56      2017.12.09         6247.0        3
# 59    2017.11.25.R         6244.0        4
# ...            ...            ...      ...
# 6304           NaN         6306.0       20
# 6305           NaN         6307.0       20
# 6306           NaN         6308.0       20
# 6307           NaN         6309.0       20
# 6308           NaN         6310.0       20
#
# [462 rows x 23 columns]

# %%
sharks1.head()
# Out:
#    CaseNumber         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               Injury Fatal_bin           Time  \
# 0  No injury to occupant, outrigger canoe and pad...         N          18h00
# 1                         Minor injury to left thigh         N  14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg         N          07h45
# 3                          Minor injury to lower leg         N            NaN
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT         N            NaN
#
#            Species            InvestigatororSource                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                          hrefformula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href CaseNumber1 CaseNumber2  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.25  2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.18  2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.09  2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.08  2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.04  2018.06.04
#
#    originalorder  num_nan
# 0         6303.0        0
# 1         6302.0        1
# 2         6301.0        1
# 3         6300.0        2
# 4         6299.0        2

# %%
check_nan(sharks1)
# Out:
# 'N nan cols: 20'
# CaseNumber               0.015850
# Date                     0.110953
# Year                     0.142653
# Type                     0.174354
# Area                     7.322872
# Location                 8.670154
# Activity                 8.733555
# Name                     3.439531
# Sex                      9.066413
# Age                     44.983357
# Injury                   0.554763
# Fatal_bin                8.654303
# Time                    53.273102
# Species                 45.094310
# InvestigatororSource     0.380409
# pdf                      0.110953
# hrefformula              0.126803
# href                     0.110953
# CaseNumber1              0.110953
# CaseNumber2              0.110953
# dtype: float64

# %%
sharks1[['Type', 'Activity','Name','Sex','Age','Time','Fatal_bin','Species','Location','Area','Injury']] = sharks1[['Type', 'Activity','Name','Sex','Age','Time','Fatal_bin','Species','Location','Area','Injury']].fillna('unknown')

# %%
check_nan(sharks1)
# Out:
# 'N nan cols: 9'
# CaseNumber              0.015850
# Date                    0.110953
# Year                    0.142653
# InvestigatororSource    0.380409
# pdf                     0.110953
# hrefformula             0.126803
# href                    0.110953
# CaseNumber1             0.110953
# CaseNumber2             0.110953
# dtype: float64

# %%
sharks1.Name.value_counts()[:40]
# Out:
# male                          550
# unknown                       220
# female                         97
# boy                            23
# 2 males                        16
# boat                           14
# child                          12
# males                          10
# sailor                         10
# Anonymous                      10
# a sailor                        8
# girl                            7
# fisherman                       6
# a pearl diver                   6
# Unidentified                    6
# a soldier                       5
# a native                        5
# 2 fishermen                     4
# Arab boy                        4
# black male                      4
# Unknown                         4
# Andre Hartman                   3
# 2 women                         3
# Japanese diver                  3
# aboriginal male                 3
#  male                           3
# woman                           3
# Russian male                    3
# M.C.                            3
# Zulu male                       3
# native boy                      3
# John Williams                   3
# dinghy                          3
# Gordon Harmer                   2
# Rory OConnor                   2
# Mr. Meyer                       2
# Michael Massey                  2
# Hideo Ishida                    2
# a pilot                         2
# male, a Japanese fisherman      2
# Name: Name, dtype: int64

# %%
sharks1['Type'] = sharks1['Type'].replace(['Boat','Boatomg'], 'Boating')

# %%
new_column2 = []
for c in sharks1.Age:
    c = c.replace(" ","")
  
    
    
    new_column2.append(c)
sharks1.Age = new_column2

# %%
sharks1.Age.value_counts()
# Out:
# unknown    2838
# 17          154
# 18          150
# 20          142
# 19          142
#            ...
# 32&30         1
# 60's          1
# 20?           1
# 7&31          1
# 13or14        1
# Name: Age, Length: 151, dtype: int64

# %%
import re

re.findall('\d+', '13uasdiuhadsu12askjdaks14')[:3]
# Out:
# ['13', '12', '14']

# %%
from statistics import mean
def mean_Age(x):
    x = x.lower()
    num=re.findall('\d+', x)[:5]
    
    
    res = [eval(i) for i in num]
    

    if num:
        return mean(res)
    elif "teen" in x:
        return 15.5
    elif "young" in x:
        return 18.5
    elif "adult" in x:
        return 49
    elif "elderly" in x:
        return 70
    elif "middle" in x :
        return 50
    elif "18months" in x:
        return 1.5
    elif "9months" in x:
        return 0.75
    elif "2to3months" in x:
        return 0.2
    else:
        return 0

# %%
sharks1['mean_age']=sharks1.Age.apply(mean_Age)

# %%
keyword='67'
select=sharks1[sharks1.Age.str.contains(keyword, regex=True)]
select
# Out:
#       CaseNumber         Date    Year     Type Country        Area  \
# 2848  1985.08.17  17-Aug-1985  1985.0  Invalid     USA     Florida
# 3986  1960.06.07  07-Jun-1960  1960.0  Invalid     USA  California
#
#                                               Location  \
# 2848                          Bayport, Hernando County
# 3986  10 miles off Santa Barbara, Santa Barbara County
#
#                                                Activity  \
# 2848                                       Scuba diving
# 3986  Testing classified underwater electronic gear ...
#
#                                                    Name Sex               Age  \
# 2848                               Thomas Robert Sewell   M                67
# 3986  Paul Timothy Lovette, Dr. Neal Beardsley, Jame...   M  37,67,35,27,?&27
#
#                                                  Injury Fatal_bin     Time  \
# 2848  Body not recovered. 3 days later some of his e...   unknown    10h30
# 3986  Legs & arms bitten, coroner unable to determin...   unknown  unknown
#
#                                                 Species  \
# 2848     Shark involvement prior to death not confirmed
# 3986  Shark involvement prior to death was not confi...
#
#                                    InvestigatororSource  \
# 2848  E. Pace, GSAF; J. McAniff, NUADC;  Orlando Sen...
# 3986  L.A. Times, 6/10/1960; L. Schultz & M. Malin, ...
#
#                           pdf  \
# 2848    1985.08.17-Sewell.pdf
# 3986  1960.06.07-Raytheon.pdf
#
#                                             hrefformula  \
# 2848  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3986  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href CaseNumber1  \
# 2848  http://sharkattackfile.net/spreadsheets/pdf_di...  1985.08.17
# 3986  http://sharkattackfile.net/spreadsheets/pdf_di...  1960.06.07
#
#      CaseNumber2  originalorder  num_nan  mean_age
# 2848  1985.08.17         3455.0        1      67.0
# 3986  1960.06.07         2317.0        2      38.6

# %%
sharks1.mean_age.value_counts()

# %%
sharks1.mean_age.value_counts()

# %%
sharks2 = sharks1.copy()

# %%
sharks2.Fatal_bin.value_counts()
# Out:
# n          4301
# y          1390
# unknown     618
# Name: Fatal_bin, dtype: int64

# %%
new_column3 = []
for c in sharks2.Fatal_bin:
    c = c.lower()
    c = c.replace(" ","")
    c = c.replace("m","unknown")
    c = c.replace("2017","y")
  
    
    
    new_column3.append(c)
sharks2.Fatal_bin = new_column3

# %%
keyword='.'
select2=sharks2[sharks2.Sex.str.contains(keyword, regex=True)]
select2
# Out:
#       CaseNumber         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# ...          ...          ...     ...         ...        ...              ...
# 6304           0          NaN     NaN     unknown    unknown          unknown
# 6305           0          NaN     NaN     unknown    unknown          unknown
# 6306           0          NaN     NaN     unknown    unknown          unknown
# 6307           0          NaN     NaN     unknown    unknown          unknown
# 6308           0          NaN     NaN     unknown    unknown          unknown
#
#                             Location     Activity             Name      Sex  \
# 0        Oceanside, San Diego County     Paddling      Julie Wolfe        F
# 1     St. Simon Island, Glynn County     Standing  Adyson McNeely         F
# 2                       Habush, Oahu      Surfing      John Denges        M
# 3                 Arrawarra Headland      Surfing             male        M
# 4                           La Ticla  Free diving   Gustavo Ramos         M
# ...                              ...          ...              ...      ...
# 6304                         unknown      unknown          unknown  unknown
# 6305                         unknown      unknown          unknown  unknown
# 6306                         unknown      unknown          unknown  unknown
# 6307                         unknown      unknown          unknown  unknown
# 6308                         unknown      unknown          unknown  unknown
#
#           Age                                             Injury Fatal_bin  \
# 0          57  No injury to occupant, outrigger canoe and pad...         n
# 1          11                         Minor injury to left thigh         n
# 2          48       Injury to left lower leg from surfboard skeg         n
# 3     unknown                          Minor injury to lower leg         n
# 4     unknown  Lacerations to leg & hand shark PROVOKED INCIDENT         n
# ...       ...                                                ...       ...
# 6304  unknown                                            unknown   unknown
# 6305  unknown                                            unknown   unknown
# 6306  unknown                                            unknown   unknown
# 6307  unknown                                            unknown   unknown
# 6308  unknown                                            unknown   unknown
#
#                Time          Species            InvestigatororSource  \
# 0             18h00      White shark                R. Collier, GSAF
# 1     14h00  -15h00          unknown  K.McMurray, TrackingSharks.com
# 2             07h45          unknown  K.McMurray, TrackingSharks.com
# 3           unknown        2 m shark                  B. Myatt, GSAF
# 4           unknown  Tiger shark, 3m                       A .Kipper
# ...             ...              ...                             ...
# 6304        unknown          unknown                             NaN
# 6305        unknown          unknown                             NaN
# 6306        unknown          unknown                             NaN
# 6307        unknown          unknown                             NaN
# 6308        unknown          unknown                             NaN
#
#                            pdf  \
# 0         2018.06.25-Wolfe.pdf
# 1       2018.06.18-McNeely.pdf
# 2        2018.06.09-Denges.pdf
# 3     2018.06.08-Arrawarra.pdf
# 4         2018.06.04-Ramos.pdf
# ...                        ...
# 6304                       NaN
# 6305                       NaN
# 6306                       NaN
# 6307                       NaN
# 6308                       NaN
#
#                                             hrefformula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                                                    href CaseNumber1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.04
# ...                                                 ...         ...
# 6304                                                NaN         NaN
# 6305                                                NaN         NaN
# 6306                                                NaN         NaN
# 6307                                                NaN         NaN
# 6308                                                NaN         NaN
#
#      CaseNumber2  originalorder  num_nan  mean_age
# 0     2018.06.25         6303.0        0      57.0
# 1     2018.06.18         6302.0        1      11.0
# 2     2018.06.09         6301.0        1      48.0
# 3     2018.06.08         6300.0        2       0.0
# 4     2018.06.04         6299.0        2       0.0
# ...          ...            ...      ...       ...
# 6304         NaN         6306.0       20       0.0
# 6305         NaN         6307.0       20       0.0
# 6306         NaN         6308.0       20       0.0
# 6307         NaN         6309.0       20       0.0
# 6308         NaN         6310.0       20       0.0
#
# [6309 rows x 24 columns]

# %%
sharks2.Sex.unique()
# Out:
# array(['F', 'M', 'unknown'], dtype=object)

# %%
new_column4 = []
for c in sharks2.Sex:
    
    c = c.replace(" ","")
    c = c.replace("lli","M")
    c = c.replace("N","unknown")
    c = c.replace(".","unknown")
  
    
    
    new_column4.append(c)
sharks2.Sex = new_column4

# %%
lst=[]
for x in sharks2.CaseNumber:
    x= str(x)
    lst.append('-'.join(x.split('.')[:3]))

# %%
sharks2['CaseNumber']=lst #SOBREESCRIBIR la lista a la columna

sharks2['CaseNumber'][sharks2['CaseNumber'].str.startswith('ND')] = 'unknown' 

sharks2['CaseNumber'][sharks2['CaseNumber'].str.startswith('0')] = 'unknown' 

sharks2['CaseNumber'][sharks2['CaseNumber'].str.startswith('x')] ='unknown'

# %%
sharks2.CaseNumber.value_counts()
# Out:
# Unknown       135
# 1950-00-00     13
# 1957-00-00     11
# 1942-00-00     11
# 1960-00-00     10
#              ...
# 1995-06-16      1
# 1995-06-23      1
# 1995-06-24      1
# 1995-06-30      1
# 1977-12-31      1
# Name: CaseNumber, Length: 5208, dtype: int64

# %%
sharks2.dtypes
# Out:
# CaseNumber               object
# Date                     object
# Year                    float64
# Type                     object
# Country                  object
# Area                     object
# Location                 object
# Activity                 object
# Name                     object
# Sex                      object
# Age                      object
# Injury                   object
# Fatal_bin                object
# Time                     object
# Species                  object
# InvestigatororSource     object
# pdf                      object
# hrefformula              object
# href                     object
# CaseNumber1              object
# CaseNumber2              object
# originalorder           float64
# num_nan                   int64
# mean_age                float64
# dtype: object

# %%
sharks2.Species.value_counts()
# Out:
# unknown                                                                                                                          2845
# White shark                                                                                                                       163
# Shark involvement prior to death was not confirmed                                                                                105
# Invalid                                                                                                                           102
# Shark involvement not confirmed                                                                                                    88
#                                                                                                                                  ...
# 1.2 m to 1.5 m [4.5' to 5'] shark                                                                                                   1
# Bull shark, 2.3 m [7.5']                                                                                                            1
# 0.9 m  [3'] shark                                                                                                                   1
# Mako shark, 14'                                                                                                                     1
# Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable       1
# Name: Species, Length: 1550, dtype: int64

# %%
sharks2.Species.value_counts()[:10]
# Out:
# unknown                                               2845
# White shark                                            163
# Shark involvement prior to death was not confirmed     105
# Invalid                                                102
# Shark involvement not confirmed                         88
# Tiger shark                                             73
# Shark involvement prior to death unconfirmed            68
# Bull shark                                              52
# 4' shark                                                40
# 6' shark                                                40
# Name: Species, dtype: int64

# %%
keyword='not confirmed'
select2=sharks2[sharks2.Species.str.contains(keyword, regex=True)]
select2
# Out:
# Empty DataFrame
# Columns: [CaseNumber, Date, Year, Type, Country, Area, Location, Activity, Name, Sex, Age, Injury, Fatal_bin, Time, Species, InvestigatororSource, pdf, hrefformula, href, CaseNumber1, CaseNumber2, originalorder, num_nan, mean_age]
# Index: []

# %%
sharks2.shape
# Out:
# (6309, 24)

# %%
new_column5= []
t= "not confirmed"
for c in sharks2.Species:
    if t in c:
        new_column5.append("unknown")
    else:
        new_column5.append(c)
  
    
    
    
sharks2.Species = new_column5

# %%
sharks2.Species.value_counts()
# Out:
# unknown                                                                                                                          3070
# white shark                                                                                                                       634
# invalid                                                                                                                           102
# tiger shark                                                                                                                        73
# shark involvement prior to death unconfirmed                                                                                       68
#                                                                                                                                  ...
# mako shark, 14'                                                                                                                     1
# 0.9 m  [3'] shark                                                                                                                   1
# bull shark, 2.3 m [7.5']                                                                                                            1
# 1.2 m to 1.5 m [4.5' to 5'] shark                                                                                                   1
# said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable       1
# Name: Species, Length: 1211, dtype: int64

# %%
new_column6= []
t= "White Shark"

for c in sharks2.Species:
   
    t = t.lower()
    if t in c.lower():
        new_column6.append(t)
    else:
        new_column6.append(c.lower())
  
    
    
    
sharks2.Species = new_column6

# %%
keyword='invalid'
select2=sharks2[sharks2.Species.str.contains(keyword, regex=True)]
select2
# Out:
#       CaseNumber                   Date    Year     Type  \
# 13    2018-05-13            13-May-2018  2018.0  Invalid
# 226   2016-09-00               Sep-2016  2016.0  Invalid
# 578   2014-03-13            13-Mar-2014  2014.0  Invalid
# 676   2013-05-08            08-May-2013  2013.0  Invalid
# 926   2011-05-07   Reported 07-May-2011  2011.0  Invalid
# ...          ...                    ...     ...      ...
# 6005  1855-00-00             Circa 1855  1855.0  Invalid
# 6019  1852-07-28            28-Jul-1952  1852.0  Invalid
# 6088  1831-01-22  Reported 22- Jan-1831  1831.0  Invalid
# 6110  1819-07-08   Reported 08-Jul-1819  1819.0  Invalid
# 6232     Unknown   No date, Before 1963     0.0  Invalid
#
#                          Country                      Area  \
# 13                       ENGLAND                  Cornwall
# 226                       MEXICO                   unknown
# 578               CAYMAN ISLANDS                   unknown
# 676                          USA                California
# 926   UNITED ARAB EMIRATES (UAE)  Umm al Qaywayan Province
# ...                          ...                       ...
# 6005                   AUSTRALIA           New South Wales
# 6019              ATLANTIC OCEAN                   unknown
# 6088                   AUSTRALIA                  Tasmania
# 6110                       SPAIN                   unknown
# 6232                         USA                    Hawaii
#
#                                     Location                         Activity  \
# 13                            Off Land's End                          Fishing
# 226                         Guadalupe Island                      Cage Diving
# 578                                  unknown  Scuba diving / culling lionfish
# 676   Tourmaline Surf Park, San Diego County                          Surfing
# 926                             Khor Fakkan                          Fishing
# ...                                      ...                              ...
# 6005                           Sydney Harbor                        Swimming
# 6019                                 unknown                          unknown
# 6088                                  Hobart  Boat capsized, clinging to line
# 6110                                   Cadiz                          unknown
# 6232                          Portlock, Oahu                           Diving
#
#                         Name      Sex      Age  \
# 13              Max Berryman        M       21
# 226                  unknown  unknown  unknown
# 578            Jason Dimitri        M  unknown
# 676           Brandon Beaver        M       42
# 926       Mustafa Al Hammadi        M       43
# ...                      ...      ...      ...
# 6005              C.T. Clark        M  unknown
# 6019  Karen Bredesen Stræte         F        1
# 6088           Robert Dudlow        M  unknown
# 6110                    male        M  unknown
# 6232           Val Valentine        M  unknown
#
#                                                  Injury Fatal_bin     Time  \
# 13    Injured by teeth of a dead porbeagle shark he ...         n    08h15
# 226      No injury to divers, white shark breached cage   unknown  unknown
# 578   Caribbean reef shark buzzed him. No injury, no...   unknown  unknown
# 676                        Shark bites were post-mortem   unknown  unknown
# 926   Erroneously reported on several internet sites...   unknown  unknown
# ...                                                 ...       ...      ...
# 6005  No injury & although reported as an attack, it...   unknown  unknown
# 6019                   Death preceded shark involvement   unknown  unknown
# 6088                      Drowned, no shark involvement   unknown  unknown
# 6110                              No injury / No attack   unknown  unknown
# 6232  A 4.3 m [14'] shark made threat display. No in...   unknown  unknown
#
#                Species                       InvestigatororSource  \
# 13    invalid incident            K. McMurray, TrackingSharks.com
# 226            invalid                                  K. Yonker
# 578            invalid                 You Tube, posted 4/12/2014
# 676            invalid                   Sacramento Bee, 6/4/2013
# 926            invalid               Emirates 24/7 News, 5/7/2011
# ...                ...                                        ...
# 6005           invalid         Brighton Southern Cross, 2/13/1915
# 6019           invalid                            Norway Heritage
# 6088           invalid  C. Black, GSAF; Sydney Gazette, 1/22/1831
# 6110           invalid                             C. Moore, GSAF
# 6232           invalid                        B. Sojka & D. Lloyd
#
#                             pdf  \
# 13    2018.05.13.a-Berryman.pdf
# 226       2016.09.00-Breach.pdf
# 578      2014.03.13-Dimitri.pdf
# 676     2013.05.08.b-Beaver.pdf
# 926        2011.05.07.R-UAE.pdf
# ...                         ...
# 6005       1855.00.00-Clark.pdf
# 6019       1852.07.28-Karen.pdf
# 6088    1831.01.22.R-Dudlow.pdf
# 6110     1819.07.08.R-Cadiz.pdf
# 6232      ND-0081-Valentine.pdf
#
#                                             hrefformula  \
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...
# 226   http://sharkattackfile.net/spreadsheets/pdf_di...
# 578   http://sharkattackfile.net/spreadsheets/pdf_di...
# 676   http://sharkattackfile.net/spreadsheets/pdf_di...
# 926   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6005  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6019  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6088  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6110  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6232  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   CaseNumber1  \
# 13    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.13.a
# 226   http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.00
# 578   http://sharkattackfile.net/spreadsheets/pdf_di...    2014.03.13
# 676   http://sharkattackfile.net/spreadsheets/pdf_di...  2013.05.08.b
# 926   http://sharkattackfile.net/spreadsheets/pdf_di...  2011.05.07.R
# ...                                                 ...           ...
# 6005  http://sharkattackfile.net/spreadsheets/pdf_di...    1855.00.00
# 6019  http://sharkattackfile.net/spreadsheets/pdf_di...    1852.07.28
# 6088  http://sharkattackfile.net/spreadsheets/pdf_di...  1831.01.22.R
# 6110  http://sharkattackfile.net/spreadsheets/pdf_di...  1819.07.08.R
# 6232  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0081
#
#        CaseNumber2  originalorder  num_nan  mean_age
# 13    2018.05.13.a         6290.0        0      21.0
# 226     2016.09.00         6077.0        6       0.0
# 578     2014.03.13         5725.0        5       0.0
# 676   2013.05.08.b         5627.0        2      42.0
# 926   2011.05.07.R         5377.0        2      43.0
# ...            ...            ...      ...       ...
# 6005    1855.00.00          298.0        3       0.0
# 6019    1852.07.28          284.0        5       1.0
# 6088  1831.01.22.R          215.0        3       0.0
# 6110  1819.07.08.R          193.0        5       0.0
# 6232       ND.0081           71.0        3       0.0
#
# [103 rows x 24 columns]

# %%
sharks3 = sharks2.copy()

# %%
keyword = "invalid"
sharks3.drop(sharks3[sharks3.Species.str.contains(keyword, regex=True)].index, axis=0, inplace=True)

# %%
sharks3.shape
# Out:
# (6206, 24)

# %%
sharks2.shape
# Out:
# (6309, 24)

# %%
sharks3.Species[:20]
# Out:
# 0               white shark
# 1                   unknown
# 2                   unknown
# 3                 2 m shark
# 4           tiger shark, 3m
# 5                   unknown
# 6               tiger shark
# 7           lemon shark, 3'
# 8            bull shark, 6'
# 9                   unknown
# 10          grey reef shark
# 11                  unknown
# 12                  unknown
# 14    tawny nurse shark, 2m
# 15                  unknown
# 16                  unknown
# 17                  unknown
# 18              tiger shark
# 19                  unknown
# 20             questionable
# Name: Species, dtype: object

# %%
keyword='questionable'
select3=sharks3[sharks3.Species.str.contains(keyword, regex=True)]
select3
# Out:
#       CaseNumber                      Date    Year          Type  \
# 20    2018-04-25               25-Apr-2018  2018.0  Questionable
# 79    2017-09-24               24-Sep-2017  2017.0       Invalid
# 98    2017-08-26               26-Aug-2017  2017.0       Invalid
# 1107  2009-07-24               24-Jul-2009  2009.0       Invalid
# 1366  2007-07-00                  Jul-2007  2007.0       Invalid
# ...          ...                       ...     ...           ...
# 5876  1875-01-20      Reported 20-Jan-1875  1875.0       Invalid
# 5965  1862-12-04               04-Dec-1862  1862.0       Invalid
# 6164  1642-00-00  Late 1600s Reported 1728  1642.0       Invalid
# 6227     Unknown      No date, Before 1975     0.0       Invalid
# 6296     Unknown               Before 1906     0.0    Unprovoked
#
#                Country                 Area  \
# 20           AUSTRALIA      New South Wales
# 79                 USA             New York
# 98               SPAIN            Castellón
# 1107             SPAIN            Catalunya
# 1366           SENEGAL              unknown
# ...                ...                  ...
# 5876         AUSTRALIA           Queensland
# 5965       NEW ZEALAND         South Island
# 6164            GUINEA              unknown
# 6227  PAPUA NEW GUINEA  Milne Bay  Province
# 6296         AUSTRALIA      New South Wales
#
#                                               Location        Activity  \
# 20                                         Lennox Head         Surfing
# 79                                            Rockaway         Surfing
# 98                                     Grao de Moncofa        Swimming
# 1107                                     Sant Salvador        Swimming
# 1366                                           unknown          Murder
# ...                                                ...             ...
# 5876                                        Mary River         Bathing
# 5965                                        Lyttleton?         unknown
# 6164                                           unknown  Went overboard
# 6227   D'Entrecasteaux islands, 20 miles off the coast    Scuba diving
# 6296                                                          Swimming
#
#                                Name      Sex      Age  \
# 20                      Matthew Lee        M  unknown
# 79                   Michah Behrend        M       33
# 98                           female        F       11
# 1107                        unknown        F       11
# 1366                     Alex Takyi  unknown  unknown
# ...                             ...      ...      ...
# 5876                           male        M  unknown
# 5965                        unknown  unknown  unknown
# 6164  crew member of the Nieuwstadt        M  unknown
# 6227                      Dan Hogan        M  unknown
# 6296                       Arab boy        M  unknown
#
#                                                  Injury Fatal_bin     Time  \
# 20                                            No injury         n    07h00
# 79               Lacerations to right ankle, foot & toe   unknown    15h30
# 98                             Lacerations to left foot   unknown   Midday
# 1107                            Laceration to left foot   unknown    10h15
# 1366                                            unknown   unknown  unknown
# ...                                                 ...       ...      ...
# 5876                                    Forehead bitten   unknown  unknown
# 5965                                            unknown   unknown  unknown
# 6164                                              FATAL   unknown  unknown
# 6227  Said to be fatal and involve a 4.6 m to 6 m [1...         y  unknown
# 6296                                              FATAL         y  unknown
#
#                                                 Species  \
# 20                                         questionable
# 79                                         questionable
# 98                       shark involvement questionable
# 1107                     shark involvement questionable
# 1366                              questionable incident
# ...                                                 ...
# 5876                     shark involvement questionable
# 5965                              questionable incident
# 6164                                       questionable
# 6227                                       questionable
# 6296  said to involve a grey nurse shark that leapt ...
#
#                                    InvestigatororSource  \
# 20                                       B. Myatt, GSAF
# 79                            S. Curatolo-Wageman, GSAF
# 98                 El Periodico Mediterraneo, 8/27/2017
# 1107                               ABC-Spain, 7/25/2009
# 1366                             Daily Guide, 8/20/2007
# ...                                                 ...
# 5876                     Nelson Evening Mail, 1/20/1875
# 5965                       Bendigo Advertiser, 1/3/1863
# 6164  History of the Pyrates, by D. Defoe, Vol. 2, p.28
# 6227                                F. Dennis, pp.15-16
# 6296  L. Becke in New York Sun, 9/9/1906; L. Schultz...
#
#                                pdf  \
# 20            2018.04.25.b-Lee.pdf
# 79        2017.09.24.b-Behrend.pdf
# 98          2017.08.26.b-Spain.pdf
# 1107        2009.07.24.a-Spain.pdf
# 1366          2007.07.00-Takyi.pdf
# ...                            ...
# 5876    1875.01.20.R-MaryRiver.pdf
# 5965      1862.12.04-Lyttleton.pdf
# 6164   1642.00.00.b-Nieuwstadt.pdf
# 6227          ND-0086-DanHogan.pdf
# 6296  ND-0006-ArabBoy-Prymount.pdf
#
#                                             hrefformula  \
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...
# 79    http://sharkattackfile.net/spreadsheets/pdf_di...
# 98    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1107  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1366  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5876  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5965  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6227  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   CaseNumber1  \
# 20    http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.25.b
# 79    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 98    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
# 1107  http://sharkattackfile.net/spreadsheets/pdf_di...  2009.07.24.a
# 1366  http://sharkattackfile.net/spreadsheets/pdf_di...    2007.07.00
# ...                                                 ...           ...
# 5876  http://sharkattackfile.net/spreadsheets/pdf_di...  1875.01.20.R
# 5965  http://sharkattackfile.net/spreadsheets/pdf_di...    1862.12.04
# 6164  http://sharkattackfile.net/spreadsheets/pdf_di...  1642.00.00.b
# 6227  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0086
# 6296  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
#
#        CaseNumber2  originalorder  num_nan  mean_age
# 20    2018.04.25.b         6283.0        1       0.0
# 79    2017.09.24.b         6224.0        1      33.0
# 98    2017.08.26.b         6205.0        1      11.0
# 1107  2009.07.24.a         5196.0        2      11.0
# 1366    2007.07.00         4937.0        7       0.0
# ...            ...            ...      ...       ...
# 5876  1875.01.20.R          427.0        3       0.0
# 5965    1862.12.04          338.0        7       0.0
# 6164  1642.00.00.b          139.0        5       0.0
# 6227       ND.0086           76.0        2       0.0
# 6296       ND.0006            7.0        2       0.0
#
# [83 rows x 24 columns]
